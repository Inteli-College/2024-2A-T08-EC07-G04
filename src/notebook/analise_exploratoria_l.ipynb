# %%
# Importa biblioteca pandas

import pandas as pd

# Carregamento das tabelas

# Tabelas de Resultados
resultados_02 = pd.read_excel('RESULTADOS_02_03_2024.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
resultados_04 = pd.read_excel('RESULTADOS_04_06_2024.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
resultados_06 = pd.read_excel('RESULTADOS_06_2023_07_2023.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
resultados_08 = pd.read_excel('RESULTADOS_08_2023_09_2023.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
resultados_10 = pd.read_excel('RESULTADOS_10_2023_11_2023.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
resultados_12 = pd.read_excel('RESULTADOS_12_2023_01_2024.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Tabelas de Falhas
falhas_04 = pd.read_excel('FALHAS_04_05_06_2024.xlsx')
falhas_predict = pd.read_excel('FALHAS_PREDICT.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Tabela do Status da Predição
status = pd.read_excel('STATUS_PREDICTOR_ANO.xlsx')
# Out:
# /home/fillmore/venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Concatenando as Tabelas de Resultados
resultados = pd.concat([resultados_02, resultados_04, resultados_06, resultados_08, resultados_10, resultados_12])

# %%
# Concatenando as Tabelas de Falhas 
falhas = pd.concat([falhas_04, falhas_predict])

# %%
resultados
# Out:
#          Unnamed: 0    Unnamed: 1            Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0               NaN           KNR                  NAME         ID     STATUS
# 1               NaN  2023-5076008  SECTION_ZP8_00000001        718         13
# 2               NaN  2023-5076008  SECTION_ZP8_00000001        718         13
# 3               NaN  2023-5076008  SECTION_ZP8_00000001        718         10
# 4               NaN  2023-5076015  SECTION_ZP8_00000001        718         13
# ...             ...           ...                   ...        ...        ...
# 1048569         NaN  2023-4926054                524400          2         10
# 1048570         NaN  2023-4926054                524400          2         10
# 1048571         NaN  2023-4926054                524400          2         10
# 1048572         NaN  2023-4926054                524400          2         10
# 1048573         NaN  2023-4926054                550100          2         10
#
# ...

# %%
resultados = resultados.drop(columns=['Unnamed: 0'])
resultados.columns = resultados.iloc[0]
resultados = resultados[1 :]

# %%
resultados
# Out:
# 0                 KNR                  NAME   ID STATUS        UNIT VALUE_ID  \
# 1        2023-5076008  SECTION_ZP8_00000001  718     13  V                80
# 2        2023-5076008  SECTION_ZP8_00000001  718     13  V                80
# 3        2023-5076008  SECTION_ZP8_00000001  718     10  V                80
# 4        2023-5076015  SECTION_ZP8_00000001  718     13  V                80
# 5        2023-5076015  SECTION_ZP8_00000001  718     10  V                80
# ...               ...                   ...  ...    ...         ...      ...
# 1048569  2023-4926054                524400    2     10  Grad              1
# 1048570  2023-4926054                524400    2     10  Grad              3
# 1048571  2023-4926054                524400    2     10  Nm                0
# 1048572  2023-4926054                524400    2     10  Nm                2
# 1048573  2023-4926054                550100    2     10  Grad              1
#
# ...

# %%
falhas = falhas.drop(columns=['Unnamed: 0'])
falhas.columns = falhas.iloc[0]
falhas = falhas[1 :]

# %%
falhas
# Out:
# 0                KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1       2023-2056234  T-CROSS  2R2R   DHS  HCEQS506  4013334  ZP7
# 2       2023-2056234  T-CROSS  2R2R   DHS  HCEQS506  4013334  ZP7
# 3       2023-2056234  T-CROSS  2R2R   DHS  PCEQS620  2058570  ZP6
# 4       2023-2056234  T-CROSS  2R2R   DHS  PCEQS999  2087715  ESPC
# 5       2023-3896001  T-CROSS  0Q0Q        HCEQS203  2043971  ZP5A
# ...              ...      ...   ...   ...       ...      ...   ...
# 663816  2024-1336453  T-CROSS  K2K2   DHS  HCEQS506  2051427  ZP7
# 663817  2024-1336485  T-CROSS  0Q0Q   DHS  HCEQS506  2044862  ZP7
# 663818  2024-1346004  T-CROSS  A1A1   DHS  HCEQS506  2052733  ZP7
# 663819  2024-1336453  T-CROSS  K2K2   DHS  HCEQS506  2051427  ZP7
# 663820  2024-1336485  T-CROSS  0Q0Q   DHS  HCEQS506  2044862  ZP7
#
# 0                                        FALHA                        DATA
# 1              PARALAMA DIANTEIRO 01. AMASSADO  2024-05-20 21:31:51.992000
# ...

# %%
status = status.drop(columns=['Unnamed: 0'])
status.columns = status.iloc[0]
status = status[1 :]

# %%
status
# Out:
# 0                 KNR STATUS                 DATA
# 1        2023-2016173   G620  2023-06-06 07:50:27
# 2        2023-2016173   M620  2023-06-06 07:50:27
# 3        2023-2026032   G620  2023-06-20 17:35:51
# 4        2023-2026032   M620  2023-06-20 17:35:51
# 5        2023-2026085   G620  2023-06-22 20:22:36
# ...               ...    ...                  ...
# 1048569  2023-4026001   G800  2023-10-05 06:18:10
# 1048570  2023-4026002   A600  2023-09-28 14:32:41
# 1048571  2023-4026002   R100  2023-09-28 14:32:42
# 1048572  2023-4026002   R120  2023-09-29 00:09:03
# 1048573  2023-4026002   R480  2023-09-29 07:02:34
#
# [1048573 rows x 3 columns]

# %%
resultados.columns
# Out:
# Index(['KNR', 'NAME', 'ID', 'STATUS', 'UNIT', 'VALUE_ID', 'VALUE', 'DATA'], dtype='object', name=0)

# %%
falhas.columns
# Out:
# Index(['KNR', 'MODELO', 'COR', 'MOTOR', 'ESTACAO', 'USUARIO', 'HALLE', 'FALHA',
#        'DATA'],
#       dtype='object', name=0)

# %%
status.columns
# Out:
# Index(['KNR', 'STATUS', 'DATA'], dtype='object', name=0)

# %%
predict = pd.read_csv('PREDICT_VW_M7_EC.csv', low_memory=False)

# %%
predict
# Out:
#                                                      KNR  \
# 0                                           2024-0316012
# 1                                           2024-0316022
# 2                                           2024-0316030
# 3                                           2024-0316046
# 4                                           2024-0316047
# ...                                                  ...
# 35390  2024-0336306;T-Cross 1.4  HIGH   150cv  A6F;44...
# 35391  2024-0336316;T-Cross 1.4  HIGH   150cv  A6F;39...
# 35392  2024-0336329;T-Cross 1.4  HIGH   150cv  A6F;45...
# 35393  2024-0336342;T-Cross 1.4  HIGH   150cv  A6F;45...
# 35394  2024-0336362;T-Cross 1.4  HIGH   150cv  A6F;45...
#
#                                   MOD  TEMPO_MONT  TEMPO_BODY  TEMPO_ZP5  \
# 0      T-Cross 1.0  TPLUS  128cv  A6F       431.0       873.0       11.0
# 1      T-Cross 1.0  TPLUS  128cv  A6F       431.0       843.0       13.0
# ...
