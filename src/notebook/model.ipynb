# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tabela_da_felicidade.csv')

# %%
df.head()
# Out:
#             KNR    NAME  ID  STATUS        UNIT  VALUE_ID  \
# 0  2024-1346277  042000   1      10  Deg              5.0
# 1  2024-1346277  042000   1      10  mm               2.0
# 2  2024-1346277  042000   1      10  mm               3.0
# 3  2024-1346277  042000   1      10  mm               1.0
# 4  2024-1346277  042000   1      10  Nm               4.0
#
#                                                VALUE               DATA_x  \
# 0  15427                                         ...  2024-03-27 15:12:07
# 1  1.76                                          ...  2024-03-27 15:12:07
# 2  1.95                                          ...  2024-03-27 15:12:07
# 3  3.71                                          ...  2024-03-27 15:12:07
# 4  3.38                                          ...  2024-03-27 15:12:07
#
#     COR MOTOR  USUARIO                                    FALHA  \
# 0  K2K2   CWL  2079860  console central ruído de corpo estranho
# 1  K2K2   CWL  2079860  console central ruído de corpo estranho
# 2  K2K2   CWL  2079860  console central ruído de corpo estranho
# 3  K2K2   CWL  2079860  console central ruído de corpo estranho
# 4  K2K2   CWL  2079860  console central ruído de corpo estranho
#
#                        DATA_y
# 0  2024-04-05 16:50:34.322000
# 1  2024-04-05 16:50:34.322000
# 2  2024-04-05 16:50:34.322000
# 3  2024-04-05 16:50:34.322000
# 4  2024-04-05 16:50:34.322000

# %%
from sklearn.preprocessing import LabelEncoder
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 2.0.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/rafa/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/rafa/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/rafa/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/rafa/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/rafa/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/rafa/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/rafa/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/rafa/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/rafa/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10334/72097526.py", line 1, in <module>
#     from sklearn.preprocessing import LabelEncoder
#   File "/usr/lib/python3/dist-packages/sklearn/__init__.py", line 80, in <module>
#     from .base import clone
#   File "/usr/lib/python3/dist-packages/sklearn/base.py", line 21, in <module>
#     from .utils import _IS_32BIT
#   File "/usr/lib/python3/dist-packages/sklearn/utils/__init__.py", line 20, in <module>
#     from scipy.sparse import issparse
#   File "/usr/lib/python3/dist-packages/scipy/sparse/__init__.py", line 267, in <module>
#     from ._csr import *
#   File "/usr/lib/python3/dist-packages/scipy/sparse/_csr.py", line 10, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder
#
# File /usr/lib/python3/dist-packages/sklearn/__init__.py:80
#      78 from . import _distributor_init  # noqa: F401
#      79 from . import __check_build  # noqa: F401
# ---> 80 from .base import clone
#      81 from .utils._show_versions import show_versions
#      83 __all__ = ['calibration', 'cluster', 'covariance', 'cross_decomposition',
#      84            'datasets', 'decomposition', 'dummy', 'ensemble', 'exceptions',
#      85            'experimental', 'externals', 'feature_extraction',
#    (...)
#      94            'clone', 'get_config', 'set_config', 'config_context',
#      95            'show_versions']
#
# File /usr/lib/python3/dist-packages/sklearn/base.py:21
#      19 from . import __version__
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
#      23 from .utils.validation import check_array
#
# File /usr/lib/python3/dist-packages/sklearn/utils/__init__.py:20
#      18 import warnings
#      19 import numpy as np
# ---> 20 from scipy.sparse import issparse
#      22 from .murmurhash import murmurhash3_32
#      23 from .class_weight import compute_class_weight, compute_sample_weight
#
# File /usr/lib/python3/dist-packages/scipy/sparse/__init__.py:267
#     264 import warnings as _warnings
#     266 from ._base import *
# --> 267 from ._csr import *
#     268 from ._csc import *
#     269 from ._lil import *
#
# File /usr/lib/python3/dist-packages/scipy/sparse/_csr.py:10
#       7 import numpy as np
#       9 from ._base import spmatrix
# ---> 10 from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
#      11                            get_csr_submatrix)
#      12 from ._sputils import upcast, get_index_dtype
#      14 from ._compressed import _cs_matrix
#
# ImportError: numpy.core.multiarray failed to import

# %%
label_encoder = LabelEncoder()
df['FALHA'] = label_encoder.fit_transform(df['FALHA'])
