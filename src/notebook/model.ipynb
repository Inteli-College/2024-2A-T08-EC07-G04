# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tabela_da_felicidade.csv')

# %%
df.head()
# Out:
#             KNR    NAME  ID  STATUS        UNIT  VALUE_ID  \
# 0  2024-1346277  042000   1      10  Deg              5.0
# 1  2024-1346277  042000   1      10  mm               2.0
# 2  2024-1346277  042000   1      10  mm               3.0
# 3  2024-1346277  042000   1      10  mm               1.0
# 4  2024-1346277  042000   1      10  Nm               4.0
#
#                                                VALUE               DATA_x  \
# 0  15427                                         ...  2024-03-27 15:12:07
# 1  1.76                                          ...  2024-03-27 15:12:07
# 2  1.95                                          ...  2024-03-27 15:12:07
# 3  3.71                                          ...  2024-03-27 15:12:07
# 4  3.38                                          ...  2024-03-27 15:12:07
#
#     COR MOTOR  USUARIO                                    FALHA  \
# 0  K2K2   CWL  2079860  console central ruído de corpo estranho
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
df['FALHA'] = label_encoder.fit_transform(df['FALHA'])

# %%
df.head()
# Out:
#             KNR    NAME  ID  STATUS        UNIT  VALUE_ID  \
# 0  2024-1346277  042000   1      10  Deg              5.0
# 1  2024-1346277  042000   1      10  mm               2.0
# 2  2024-1346277  042000   1      10  mm               3.0
# 3  2024-1346277  042000   1      10  mm               1.0
# 4  2024-1346277  042000   1      10  Nm               4.0
#
#                                                VALUE               DATA_x  \
# 0  15427                                         ...  2024-03-27 15:12:07
# 1  1.76                                          ...  2024-03-27 15:12:07
# 2  1.95                                          ...  2024-03-27 15:12:07
# 3  3.71                                          ...  2024-03-27 15:12:07
# 4  3.38                                          ...  2024-03-27 15:12:07
#
#     COR MOTOR  USUARIO  FALHA                      DATA_y
# 0  K2K2   CWL  2079860     75  2024-04-05 16:50:34.322000
# ...

# %%
df.groupby('MOTOR').count()
# Out:
#            KNR     NAME       ID   STATUS     UNIT  VALUE_ID    VALUE  \
# MOTOR
# CWL     703722   703722   703722   703722   703722    703722   703722
# CWS       5987     5987     5987     5987     5987      5987     5987
# DHS    1029884  1029884  1029884  1029884  1029884   1029884  1029884
# DRP      75965    75965    75965    75965    75965     75965    75965
#
#         DATA_x      COR  USUARIO    FALHA   DATA_y
# MOTOR
# CWL     703722   703722   703722   703722   703722
# CWS       5987     5987     5987     5987     5987
# DHS    1029884  1029884  1029884  1029884  1029884
# DRP      75965    75965    75965    75965    75965
